# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# 1. Creating DataFrame

# %%
data = {'Name': ['Sujal', 'Teyung' , 'Limbu'],
'Age': [20, 21, 22],
'City': ['Kathmandu', 'Pokhara', 'Lalitpur']}
df = pd.DataFrame(data)
print(df)
df.to_csv('data.csv', index=False)
# Out:
#      Name  Age       City
# 0   Sujal   20  Kathmandu
# 1  Teyung   21    Pokhara
# 2   Limbu   22   Lalitpur

# %% [markdown]
# 2. Readind Dataset

# %%
info = pd.read_csv('airports.csv')
info
# Out:
#                                   Description  \
# 0                       International Airport
# 1                                Hub Airports
# 2                                Hub Airports
# 3                                Hub Airports
# 4                                Hub Airports
# 5      High Traffic Regular Domestic Airports
# 6      High Traffic Regular Domestic Airports
# 7      High Traffic Regular Domestic Airports
# 8      High Traffic Regular Domestic Airports
# 9      High Traffic Regular Domestic Airports
# 10     High Traffic Regular Domestic Airports
# 11     High Traffic Regular Domestic Airports
# 12                  Regular Domestic Airports
# 13                  Regular Domestic Airports
# 14                  Regular Domestic Airports
# 15                  Regular Domestic Airports
# 16                  Regular Domestic Airports
# 17                  Regular Domestic Airports
# 18                  Regular Domestic Airports
# ...

# %% [markdown]
# 3. Basic info of Airport of Nepal

# %%
info.describe()
# Out:
#                      Description                             Name District
# count                         56                               56       56
# unique                         7                               56       45
# top     Non-Operational Airports  Tribhuvan International Airport  Khotang
# freq                          20                                1        4

# %% [markdown]
# 4. Access Data

# %%
info['Name']                   # Single column
info[['Name','District']]         # Multiple columns
info.iloc[0:2]                # First 2 rows
# Out:
#              Description                             Name   District
# 0  International Airport  Tribhuvan International Airport  Kathmandu
# 1           Hub Airports               Biratnagar Airport     Morang

# %% [markdown]
# 5. Filtering

# %%
info[info['Name'] == 'Biratnagar Airport']
# Out:
#     Description                Name District
# 1  Hub Airports  Biratnagar Airport   Morang
